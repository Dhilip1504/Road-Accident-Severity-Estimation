# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("dataset.csv")
# Out:
# c:\python\python382\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (79,183,189) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data = data[data["MAX_SEVERITY_LEVEL"]<5]
len(data)
# Out:
# 149635

# %%
a = ["AGGRESSIVE_DRIVING","ALCOHOL_RELATED","ILLEGAL_DRUG_RELATED","MC_DRINKING_DRIVER","DRINKING_DRIVER","IMPAIRED_DRIVER","AUTOMOBILE_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CELL_PHONE","COLLISION_TYPE","CROSS_MEDIAN","HIT","SV_RUN_OFF_RD","DEER_RELATED","DISTRACTED","FATIGUE_ASLEEP","FIRE_IN_VEHICLE","NHTSA_AGG_DRIVING","OVERTURNED","SPEEDING","SPEEDING_RELATED","UNBELTED_OCC_COUNT","UNBELTED"]

# %%
b = ["AGGRESSIVE_DRIVING","MC_DRINKING_DRIVER","DRINKING_DRIVER","AUTOMOBILE_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CELL_PHONE","COLLISION_TYPE","CROSS_MEDIAN","HIT","SV_RUN_OFF_RD","DEER_RELATED","DISTRACTED","FATIGUE_ASLEEP","FIRE_IN_VEHICLE","NHTSA_AGG_DRIVING","OVERTURNED","SPEEDING","SPEEDING_RELATED","UNBELTED_OCC_COUNT","UNBELTED"]

# %%
c = ["AGGRESSIVE_DRIVING","NHTSA_AGG_DRIVING","MC_DRINKING_DRIVER","DRINKING_DRIVER","AUTOMOBILE_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CROSS_MEDIAN","HIT","SV_RUN_OFF_RD","DEER_RELATED","DISTRACTED","FATIGUE_ASLEEP","CELL_PHONE","SPEEDING","SPEEDING_RELATED","UNBELTED_OCC_COUNT","UNBELTED",'COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED']

# %%
d = ["MC_DRINKING_DRIVER","DRINKING_DRIVER","AUTOMOBILE_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CROSS_MEDIAN","HIT","SV_RUN_OFF_RD","DEER_RELATED","DISTRACTED","FATIGUE_ASLEEP","CELL_PHONE","SPEEDING","SPEEDING_RELATED","UNBELTED_OCC_COUNT","UNBELTED",'COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED','AGGRESSIVE_DRIVING']

# %%
e = ["MC_DRINKING_DRIVER","DRINKING_DRIVER","AUTOMOBILE_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CROSS_MEDIAN","HIT","SV_RUN_OFF_RD","DEER_RELATED","DISTRACTED","FATIGUE_ASLEEP","CELL_PHONE","UNBELTED_OCC_COUNT","UNBELTED",'COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED','AGGRESSIVE_DRIVING','SPEEDING']

# %%
f = ["MC_DRINKING_DRIVER","DRINKING_DRIVER","AUTOMOBILE_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CROSS_MEDIAN","HIT","SV_RUN_OFF_RD","DEER_RELATED","UNBELTED_OCC_COUNT","UNBELTED",'COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED','AGGRESSIVE_DRIVING','SPEEDING','DISTRACTED']

# %%
g = ["MC_DRINKING_DRIVER","DRINKING_DRIVER","AUTOMOBILE_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CROSS_MEDIAN","HIT","SV_RUN_OFF_RD","DEER_RELATED","DISTRACTED","FATIGUE_ASLEEP","CELL_PHONE",'UNBELTED','COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED','AGGRESSIVE_DRIVING','SPEEDING']

# %%
h = ["MC_DRINKING_DRIVER","DRINKING_DRIVER","AUTOMOBILE_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CROSS_MEDIAN","HIT","SV_RUN_OFF_RD","DEER_RELATED",'DISTRACTED','UNBELTED','COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED','AGGRESSIVE_DRIVING','SPEEDING']

# %%
i = ["MC_DRINKING_DRIVER","DRINKING_DRIVER","AUTOMOBILE_COUNT","COMM_VEH_COUNT","BUS_COUNT","SUV_COUNT","VAN_COUNT","SCHOOL_BUS","SMALL_TRUCK_COUNT","PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT","HEAVY_TRUCK_COUNT","VEHICLE_COUNT","CROSS_MEDIAN","SV_RUN_OFF_RD",'DISTRACTED','UNBELTED','COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED','AGGRESSIVE_DRIVING','SPEEDING','HIT_BRIDGE','HIT_DEER','HIT_EMBANKMENT','HIT_FIXED_OBJECT','HIT_GDRAIL','HIT_GDRAIL_END','HIT_POLE','HIT_TREE_SHRUB','HIT_BARRIER']
i
# Out:
# ['MC_DRINKING_DRIVER',
#  'DRINKING_DRIVER',
#  'AUTOMOBILE_COUNT',
#  'COMM_VEH_COUNT',
#  'BUS_COUNT',
#  'SUV_COUNT',
#  'VAN_COUNT',
#  'SCHOOL_BUS',
#  'SMALL_TRUCK_COUNT',
#  'PED_COUNT',
#  'BICYCLE_COUNT',
#  'MOTORCYCLE_COUNT',
#  'HEAVY_TRUCK_COUNT',
#  'VEHICLE_COUNT',
#  'CROSS_MEDIAN',
#  'SV_RUN_OFF_RD',
#  'DISTRACTED',
#  'UNBELTED',
#  'COLLISION_TYPE',
#  'FIRE_IN_VEHICLE',
#  'OVERTURNED',
#  'AGGRESSIVE_DRIVING',
#  'SPEEDING',
#  'HIT_BRIDGE',
#  'HIT_DEER',
#  'HIT_EMBANKMENT',
#  'HIT_FIXED_OBJECT',
#  'HIT_GDRAIL',
#  'HIT_GDRAIL_END',
#  'HIT_POLE',
#  'HIT_TREE_SHRUB',
#  'HIT_BARRIER']

# %%
j = ["MC_DRINKING_DRIVER","DRINKING_DRIVER","CROSS_MEDIAN","SV_RUN_OFF_RD",'DISTRACTED','UNBELTED','COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED','AGGRESSIVE_DRIVING','SPEEDING','HIT_BRIDGE','HIT_DEER','HIT_EMBANKMENT','HIT_FIXED_OBJECT','HIT_GDRAIL','HIT_GDRAIL_END','HIT_POLE','HIT_TREE_SHRUB','HIT_BARRIER']
j

# %%
small = ["PED_COUNT","BICYCLE_COUNT","MOTORCYCLE_COUNT"]
medium = ["AUTOMOBILE_COUNT","SUV_COUNT"]
large = ["VAN_COUNT","SMALL_TRUCK_COUNT","HEAVY_TRUCK_COUNT","BUS_COUNT","SCHOOL_BUS"]

# %%
data["SMALL_VEH"] = data["BICYCLE_COUNT"] + data["MOTORCYCLE_COUNT"]
data["MEDIUM_VEH"] = data["AUTOMOBILE_COUNT"] + data["SUV_COUNT"]
data["LARGE_VEH"] = data["VAN_COUNT"] + data["SMALL_TRUCK_COUNT"] + data["BUS_COUNT"] + data["SCHOOL_BUS"] + data["HEAVY_TRUCK_COUNT"]

# %%
data.groupby(["SV_RUN_OFF_RD","COLLISION_TYPE"]).count().reset_index()

# %%
s1 = 'MEDIUM_VEH'
df = data.groupby([s1,"MAX_SEVERITY_LEVEL"]).agg({s1: 'count'})

df.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))

# %%
 # MEDIUM VEHICLES ARE NOT LINEAR WITH SEVERITY BECAUSE SMALL AND LARGE ARE ONLY VULNERABLE

# %%
data[["MC_DRINKING_DRIVER","DRINKING_DRIVER","CROSS_MEDIAN","SV_RUN_OFF_RD",'DISTRACTED','UNBELTED','COLLISION_TYPE','FIRE_IN_VEHICLE','OVERTURNED','AGGRESSIVE_DRIVING','SPEEDING','HIT_BRIDGE','HIT_DEER','HIT_EMBANKMENT','HIT_FIXED_OBJECT','HIT_GDRAIL','HIT_GDRAIL_END','HIT_POLE','HIT_TREE_SHRUB','HIT_BARRIER']].corr()
# Out:
#                     MC_DRINKING_DRIVER  DRINKING_DRIVER  CROSS_MEDIAN  \
# MC_DRINKING_DRIVER            1.000000         0.144546      0.007733
# DRINKING_DRIVER               0.144546         1.000000      0.067629
# CROSS_MEDIAN                  0.007733         0.067629      1.000000
# SV_RUN_OFF_RD                 0.032635         0.184881     -0.019880
# DISTRACTED                   -0.014839        -0.046874     -0.012667
# UNBELTED                     -0.013645         0.118021      0.032054
# COLLISION_TYPE                0.001370         0.119054      0.004034
# FIRE_IN_VEHICLE              -0.003177        -0.009526     -0.006092
# OVERTURNED                   -0.002560         0.074006      0.000798
# AGGRESSIVE_DRIVING           -0.000043        -0.079028     -0.060073
# SPEEDING                      0.042265         0.140170      0.025520
# HIT_BRIDGE                    0.004508         0.017457      0.003122
# HIT_DEER                     -0.003515        -0.037654     -0.014403
# HIT_EMBANKMENT                0.004324         0.048558      0.002665
# HIT_FIXED_OBJECT              0.011863         0.174191     -0.019055
# HIT_GDRAIL                    0.007937         0.046765     -0.002762
# HIT_GDRAIL_END                0.006286         0.030179     -0.006501
# HIT_POLE                     -0.001481         0.104290      0.002971
# HIT_TREE_SHRUB               -0.000470         0.074965      0.008013
# HIT_BARRIER                   0.004310         0.034940     -0.019741
#
#                     SV_RUN_OFF_RD  DISTRACTED  UNBELTED  COLLISION_TYPE  \
# MC_DRINKING_DRIVER       0.032635   -0.014839 -0.013645        0.001370
# DRINKING_DRIVER          0.184881   -0.046874  0.118021        0.119054
# CROSS_MEDIAN            -0.019880   -0.012667  0.032054        0.004034
# SV_RUN_OFF_RD            1.000000   -0.055107  0.030838        0.555585
# DISTRACTED              -0.055107    1.000000  0.005044       -0.145844
# UNBELTED                 0.030838    0.005044  1.000000        0.014415
# COLLISION_TYPE           0.555585   -0.145844  0.014415        1.000000
# FIRE_IN_VEHICLE          0.087782   -0.024674  0.001919       -0.089761
# OVERTURNED               0.207725   -0.024549  0.045281        0.073130
# AGGRESSIVE_DRIVING      -0.208811   -0.249446  0.005104       -0.126200
# SPEEDING                 0.123413   -0.030849  0.076213        0.074548
# HIT_BRIDGE               0.075321   -0.007655  0.007190        0.056358
# HIT_DEER                -0.085274   -0.045021 -0.037851        0.238346
# HIT_EMBANKMENT           0.231658   -0.032050  0.024354        0.173750
# HIT_FIXED_OBJECT         0.880832   -0.049930  0.030554        0.685761
# HIT_GDRAIL               0.258429   -0.040414  0.004315        0.199890
# HIT_GDRAIL_END           0.125290    0.002663  0.001560        0.098937
# HIT_POLE                 0.361351    0.021688  0.040611        0.282585
# HIT_TREE_SHRUB           0.246666   -0.019285  0.030336        0.188822
# HIT_BARRIER              0.268070   -0.047410 -0.004252        0.210155
#
#                     FIRE_IN_VEHICLE  OVERTURNED  AGGRESSIVE_DRIVING  SPEEDING  \
# MC_DRINKING_DRIVER        -0.003177   -0.002560           -0.000043  0.042265
# DRINKING_DRIVER           -0.009526    0.074006           -0.079028  0.140170
# CROSS_MEDIAN              -0.006092    0.000798           -0.060073  0.025520
# SV_RUN_OFF_RD              0.087782    0.207725           -0.208811  0.123413
# DISTRACTED                -0.024674   -0.024549           -0.249446 -0.030849
# UNBELTED                   0.001919    0.045281            0.005104  0.076213
# COLLISION_TYPE            -0.089761    0.073130           -0.126200  0.074548
# FIRE_IN_VEHICLE            1.000000   -0.001964           -0.059233 -0.001601
# OVERTURNED                -0.001964    1.000000            0.008923  0.095982
# AGGRESSIVE_DRIVING        -0.059233    0.008923            1.000000  0.199145
# SPEEDING                  -0.001601    0.095982            0.199145  1.000000
# HIT_BRIDGE                -0.000895    0.010699           -0.011790  0.005443
# HIT_DEER                  -0.007185   -0.020255           -0.121122 -0.020693
# HIT_EMBANKMENT            -0.010687    0.289970           -0.012167  0.063795
# HIT_FIXED_OBJECT          -0.030161    0.156229           -0.162000  0.120812
# HIT_GDRAIL                -0.010073    0.047264           -0.000806  0.040948
# HIT_GDRAIL_END            -0.002514    0.019855           -0.018805  0.016813
# HIT_POLE                  -0.012070    0.004868           -0.115033  0.059356
# HIT_TREE_SHRUB            -0.007220    0.044904           -0.044544  0.066388
# HIT_BARRIER               -0.010683    0.037998            0.028220  0.044740
#
#                     HIT_BRIDGE  HIT_DEER  HIT_EMBANKMENT  HIT_FIXED_OBJECT  \
# MC_DRINKING_DRIVER    0.004508 -0.003515        0.004324          0.011863
# DRINKING_DRIVER       0.017457 -0.037654        0.048558          0.174191
# CROSS_MEDIAN          0.003122 -0.014403        0.002665         -0.019055
# SV_RUN_OFF_RD         0.075321 -0.085274        0.231658          0.880832
# DISTRACTED           -0.007655 -0.045021       -0.032050         -0.049930
# UNBELTED              0.007190 -0.037851        0.024354          0.030554
# COLLISION_TYPE        0.056358  0.238346        0.173750          0.685761
# FIRE_IN_VEHICLE      -0.000895 -0.007185       -0.010687         -0.030161
# OVERTURNED            0.010699 -0.020255        0.289970          0.156229
# AGGRESSIVE_DRIVING   -0.011790 -0.121122       -0.012167         -0.162000
# SPEEDING              0.005443 -0.020693        0.063795          0.120812
# HIT_BRIDGE            1.000000 -0.007626       -0.002535          0.083392
# HIT_DEER             -0.007626  1.000000       -0.017990         -0.078203
# HIT_EMBANKMENT       -0.002535 -0.017990        1.000000          0.252918
# HIT_FIXED_OBJECT      0.083392 -0.078203        0.252918          1.000000
# HIT_GDRAIL            0.014569 -0.020815        0.023650          0.287215
# HIT_GDRAIL_END        0.002449 -0.011602       -0.001869          0.141634
# HIT_POLE             -0.014580 -0.034501        0.004301          0.402525
# HIT_TREE_SHRUB       -0.009346 -0.020736        0.060467          0.269379
# HIT_BARRIER           0.000574 -0.023385       -0.007844          0.302226
#
#                     HIT_GDRAIL  HIT_GDRAIL_END  HIT_POLE  HIT_TREE_SHRUB  \
# MC_DRINKING_DRIVER    0.007937        0.006286 -0.001481       -0.000470
# DRINKING_DRIVER       0.046765        0.030179  0.104290        0.074965
# CROSS_MEDIAN         -0.002762       -0.006501  0.002971        0.008013
# SV_RUN_OFF_RD         0.258429        0.125290  0.361351        0.246666
# DISTRACTED           -0.040414        0.002663  0.021688       -0.019285
# UNBELTED              0.004315        0.001560  0.040611        0.030336
# COLLISION_TYPE        0.199890        0.098937  0.282585        0.188822
# FIRE_IN_VEHICLE      -0.010073       -0.002514 -0.012070       -0.007220
# OVERTURNED            0.047264        0.019855  0.004868        0.044904
# AGGRESSIVE_DRIVING   -0.000806       -0.018805 -0.115033       -0.044544
# SPEEDING              0.040948        0.016813  0.059356        0.066388
# HIT_BRIDGE            0.014569        0.002449 -0.014580       -0.009346
# HIT_DEER             -0.020815       -0.011602 -0.034501       -0.020736
# HIT_EMBANKMENT        0.023650       -0.001869  0.004301        0.060467
# HIT_FIXED_OBJECT      0.287215        0.141634  0.402525        0.269379
# HIT_GDRAIL            1.000000       -0.003223 -0.038647       -0.011689
# HIT_GDRAIL_END       -0.003223        1.000000 -0.013482       -0.001477
# HIT_POLE             -0.038647       -0.013482  1.000000       -0.003780
# HIT_TREE_SHRUB       -0.011689       -0.001477 -0.003780        1.000000
# HIT_BARRIER           0.043834        0.003043 -0.063250       -0.041561
#
#                     HIT_BARRIER
# MC_DRINKING_DRIVER     0.004310
# DRINKING_DRIVER        0.034940
# CROSS_MEDIAN          -0.019741
# SV_RUN_OFF_RD          0.268070
# DISTRACTED            -0.047410
# UNBELTED              -0.004252
# COLLISION_TYPE         0.210155
# FIRE_IN_VEHICLE       -0.010683
# OVERTURNED             0.037998
# AGGRESSIVE_DRIVING     0.028220
# SPEEDING               0.044740
# HIT_BRIDGE             0.000574
# HIT_DEER              -0.023385
# HIT_EMBANKMENT        -0.007844
# HIT_FIXED_OBJECT       0.302226
# HIT_GDRAIL             0.043834
# HIT_GDRAIL_END         0.003043
# HIT_POLE              -0.063250
# HIT_TREE_SHRUB        -0.041561
# HIT_BARRIER            1.000000
